# %%
import pandas as pd
import numpy as np

import pycountry

import altair as alt
#import matplotlib.pyplot as plt
#import squarify

# %% [markdown]
# ### DATA

# %%
fsi2021 = pd.read_csv('data/fsi-2021.csv')

# %%
#fsi2021.head()

# %%
bp2021 = pd.read_csv('data/bp-stats-review-2021-consolidated-dataset-narrow-format.csv')
#bp2021 = bp2021.loc[ bp2021.Var == 'oilreserves_bbl']
bp2021 = bp2021.loc[ bp2021.Year == 2020]

# %%
bp2021.rename(columns={
    'ISO3166_alpha3': 'alpha3'
}, inplace=True)

# %%
#bp2021.head()

# %% [markdown]
# ### COUNTRIES AND MERGE

# %%
def get_alpha3(country):
    try:
        alpha3 = pycountry.countries.search_fuzzy(country)[0].alpha_3
    except LookupError as e:
        alpha3 = None
        
    return alpha3
        

fsi2021.loc[:, 'alpha3'] = fsi2021.loc[:, 'Country'].apply(
    get_alpha3
)

# %%
alpha3_codes = {
    'Congo Democratic Republic': 'COD',
    'Congo Republic': 'COG',
    'Guinea Bissau': 'GNB',
    'North Korea': 'PRK',
    'Laos': 'LAO',
    'South Korea': 'KOR',
    'Nigeria': 'NGA',
    'Niger': 'NER'
}

for country, code in alpha3_codes.items():
    fsi2021.loc[fsi2021.Country == country, 'alpha3'] = code

# %%
data = bp2021.merge(
    fsi2021.loc[:, ['Total', 'Rank', 'alpha3']],
    on='alpha3',
    how='left'
)

# %%
data = data.loc[
    ~data.Total.isna(),
    ['Country', 'Region', 'SubRegion', 'Var', 'Value', 'Total', 'Rank']
].rename(columns={
    'Total' : 'FSI', 'Rank': 'FSIRank'
})

# %%
data.head()
# Out:
#       Country              Region        SubRegion       Var      Value   FSI  \
# 0     Algeria              Africa  Northern Africa  wind_twh   0.008000  73.6
# 1   Argentina  S. & Cent. America    South America  wind_twh   9.470298  50.1
# 2   Australia        Asia Pacific     Asia Pacific  wind_twh  22.606892  21.8
# 3     Austria              Europe           Europe  wind_twh   6.794140  26.1
# 4  Azerbaijan                 CIS              CIS  wind_twh   0.095100  75.1
#
#   FSIRank
# 0    74th
# 1   137th
# 2   170th
# 3   166th
# 4    71st

# %% [markdown]
# ###

# %% [markdown]
# ### OIL RESERVES AND FRAGILITY

# %%
oil_reserves = data.loc[data.Var == 'oilreserves_bbl']
oil_reserves.loc[:, 'Share'] = oil_reserves.loc[:, 'Value'] / oil_reserves.loc[:, 'Value'].sum()
# Out:
# /home/d2ski/miniconda3/envs/vizlab/lib/python3.7/site-packages/pandas/core/indexing.py:1667: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.obj[key] = value

# %%
def fsi_levels(fsi):
    if fsi < 30:
        return 'Very sustainable'
    elif fsi < 40:
        return 'Sustainable'
    
    elif fsi < 50:
        return 'More stable'
    elif fsi < 60:
        return 'Stable'
    elif fsi < 70:
        return 'Less stable'
    
    elif fsi < 80:
        return 'Warning'
    elif fsi < 90:
        return 'Elevated warning'
    elif fsi < 100:
        return 'High warning'
    
    elif fsi < 110:
        return 'Alert'
    elif fsi < 120:
        return 'High alert'
    else:
        return 'Very high alert'
    
    
def get_fsi_label(fsi):
    if fsi < 40:
        return 'Sustainable'
    if fsi < 70:
        return 'Stable'
    if fsi < 100:
        return 'Warning'
    
    return 'Alert'
    
oil_reserves.loc[
    :, 'FSILabel'
] = oil_reserves.FSI.apply(get_fsi_label)

oil_reserves.loc[
    :, 'FSILevel'
] = oil_reserves.FSI.apply(fsi_levels)

# %%
oil_reserves.sort_values('Share', ascending=False).head(10)
# Out:
#                    Country              Region        SubRegion  \
# 1548             Venezuela  S. & Cent. America    South America
# 1525          Saudi Arabia         Middle East      Middle East
# 1498                Canada       North America    North America
# 1509                  Iran         Middle East      Middle East
# 1510                  Iraq         Middle East      Middle East
# 1524    Russian Federation                 CIS              CIS
# 1513                Kuwait         Middle East      Middle East
# 1545  United Arab Emirates         Middle East      Middle East
# 1544                    US       North America    North America
# 1514                 Libya              Africa  Northern Africa
#
#                   Var       Value   FSI FSIRank     Share     FSILabel  \
# 1548  oilreserves_bbl  303.805745  92.6    25th  0.176185      Warning
# 1525  oilreserves_bbl  297.527000  69.7    93rd  0.172544       Stable
# 1498  oilreserves_bbl  168.087611  21.7   171st  0.097478  Sustainable
# 1509  oilreserves_bbl  157.800000  84.5    43rd  0.091512      Warning
# 1510  oilreserves_bbl  145.019000  96.2    20th  0.084100      Warning
# 1524  oilreserves_bbl  107.804239  73.6    74th  0.062519      Warning
# 1513  oilreserves_bbl  101.500000  52.9   129th  0.058863       Stable
# 1545  oilreserves_bbl   97.800000  40.3   151st  0.056717       Stable
# 1544  oilreserves_bbl   68.757000  44.6   143rd  0.039874       Stable
# 1514  oilreserves_bbl   48.363000  97.0    17th  0.028047      Warning
#
#               FSILevel
# 1548      High warning
# 1525       Less stable
# 1498  Very sustainable
# 1509  Elevated warning
# 1510      High warning
# 1524           Warning
# 1513            Stable
# 1545       More stable
# 1544       More stable
# 1514      High warning

# %%
oil_reserves.groupby('FSILabel').agg({
    'Share': 'sum',
    'Country': 'count'
})
# Out:
#                 Share  Country
# FSILabel
# Alert        0.006959        5
# Stable       0.393397       21
# Sustainable  0.103695        4
# Warning      0.495949       19

# %%
colors = list(reversed(['#67001f','#b2182b','#d6604d','#f4a582','#fddbc7','#ffffff','#e0e0e0','#bababa','#878787','#4d4d4d','#1a1a1a']))
levels = [
    'Very sustainable',
    'Sustainable',
    'More stable',
    'Stable',
    'Less stable',
    'Warning',
    'Elevated warning',
    'High warning',
    'Alert',
    'High alert',
    'Very high alert',
]

background_color = '#00796B'
stroke_color = '#fff'

# %%
y_ticks = ['Alert', 'Warning', 'Stable', 'Sustainable']

alt.Chart(
    oil_reserves
).mark_bar(strokeWidth=0.5, stroke=background_color).encode(
    x=alt.X(
        'sum(Share)',
        axis=alt.Axis(
            grid=False,
            tickCount=4,
            labelExpr="datum.value*100 +'%'",
            labelColor=stroke_color,
            labelFontSize=12,
            labelFontWeight=400
        )
    ),
    y=alt.Y('FSILabel:O', sort=y_ticks, axis=alt.Axis( grid=False, labelColor=stroke_color, labelFontSize=12,  labelFontWeight=400)),
    color=alt.Color('FSILevel', scale=alt.Scale(
        domain=levels, range=colors
    )),
    detail='Country',
    order=alt.Order('Share'),
    tooltip=['Country', 'Share', 'FSILevel']
).configure_axis(
    domainOpacity=0,
).properties(
    width=1000,
    height=400
).configure(background=background_color)
# Out:
# alt.Chart(...)

# %% [markdown]
# #### TREEMAP

# %%
oil_reserves_agg = oil_reserves.groupby('FSILabel').agg({
    'Share': 'sum' 
}).reset_index()

fig = plt.figure(figsize=(10,10))
ax = fig.add_subplot(111)

squarify.plot(
    sizes=oil_reserves_agg['Share'].to_list(),
    label=oil_reserves_agg['FSILabel'].to_list(),
    color=['red', 'blue', 'green', 'yellow'],
    alpha=.8,
    pad=True,
    ax=ax
)
plt.axis('off')
plt.show()

# %% [markdown]
# #### STACKED AREA CHART OVER TIME?

# %% [markdown]
# ### NATURAL GAS RESERVES AND FRAGILITY

# %%
# gasreserves_tcm

gas_reserves = data.loc[data.Var == 'gasreserves_tcm']
gas_reserves.loc[:, 'Share'] = gas_reserves.loc[:, 'Value'] / gas_reserves.loc[:, 'Value'].sum()

gas_reserves.loc[
    :, 'FSILabel'
] = gas_reserves.FSI.apply(get_fsi_label)

gas_reserves.loc[
    :, 'FSILevel'
] = gas_reserves.FSI.apply(fsi_levels)
# Out:
# /home/d2ski/miniconda3/envs/vizlab/lib/python3.7/site-packages/pandas/core/indexing.py:1667: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.obj[key] = value

# %%
gas_reserves.sort_values('Share', ascending=False).head(10)
# Out:
#                    Country              Region       SubRegion  \
# 2874    Russian Federation                 CIS             CIS
# 2854                  Iran         Middle East     Middle East
# 2872                 Qatar         Middle East     Middle East
# 2890          Turkmenistan                 CIS             CIS
# 2891                    US       North America   North America
# 2847                 China        Asia Pacific    Asia Pacific
# 2896             Venezuela  S. & Cent. America   South America
# 2875          Saudi Arabia         Middle East     Middle East
# 2893  United Arab Emirates         Middle East     Middle East
# 2865               Nigeria              Africa  Western Africa
#
#                   Var      Value   FSI FSIRank     Share FSILabel  \
# 2874  gasreserves_tcm  37.391524  73.6    74th  0.200851  Warning
# 2854  gasreserves_tcm  32.101379  84.5    43rd  0.172435  Warning
# 2872  gasreserves_tcm  24.665471  44.1   144th  0.132492   Stable
# 2890  gasreserves_tcm  13.601250  68.2    97th  0.073060   Stable
# 2891  gasreserves_tcm  12.618704  44.6   143rd  0.067782   Stable
# 2847  gasreserves_tcm   8.398550  68.9    95th  0.045113   Stable
# 2896  gasreserves_tcm   6.260173  92.6    25th  0.033627  Warning
# 2875  gasreserves_tcm   6.019120  69.7    93rd  0.032332   Stable
# 2893  gasreserves_tcm   5.938725  40.3   151st  0.031900   Stable
# 2865  gasreserves_tcm   5.472979  98.0    12th  0.029398  Warning
#
#               FSILevel
# 2874           Warning
# 2854  Elevated warning
# 2872       More stable
# 2890       Less stable
# 2891       More stable
# 2847       Less stable
# 2896      High warning
# 2875       Less stable
# 2893       More stable
# 2865      High warning

# %%
gas_reserves.groupby('FSILabel').agg({
    'Share': 'sum',
    'Country': 'count'
})
# Out:
#                 Share  Country
# FSILabel
# Alert        0.002871        2
# Stable       0.439757       23
# Sustainable  0.034111        6
# Warning      0.523261       20

# %%
y_ticks = ['Alert', 'Warning', 'Stable', 'Sustainable']

alt.Chart(
    gas_reserves
).mark_bar(strokeWidth=0.5, stroke=background_color).encode(
    x=alt.X(
        'sum(Share)',
        axis=alt.Axis(
            grid=False,
            tickCount=4,
            labelExpr="datum.value*100 +'%'",
            labelColor=stroke_color,
            labelFontSize=12,
            labelFontWeight=400
        )
    ),
    y=alt.Y('FSILabel:O', sort=y_ticks, axis=alt.Axis( grid=False, labelColor=stroke_color, labelFontSize=12,  labelFontWeight=400)),
    color=alt.Color('FSILevel', scale=alt.Scale(
        domain=levels, range=colors
    )),
    detail='Country',
    order=alt.Order('Share'),
    tooltip=['Country', 'Share', 'FSILevel']
).configure_axis(
    domainOpacity=0,
).properties(
    width=1000,
    height=400
).configure(background=background_color)
# Out:
# alt.Chart(...)

# %%
alt.Chart(
    gas_reserves
).mark_bar(strokeWidth=1, stroke='#fff').encode(
    x=alt.X('sum(Share)'),
    y=alt.Y('FSILabel'),
    color=alt.Color('FSILabel', scale=alt.Scale(
        domain=['Alert', 'Stable', 'Sustainable', 'Warning'], range=['#D84315', '#78909C', '#455A64', '#FF5722']
    )),
    detail='Country',
    order=alt.Order('Share'),
    tooltip=['Country', 'Share', 'FSILabel']
).configure_axis(
    grid=False
).configure_view(
    strokeWidth=0
).properties(
    width=1000,
    height=400
)
# Out:
# alt.Chart(...)
